# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("i_a_grad.txt")

# %%
plt.plot(data[:,0])

# %%
plt.plot(data[:, 1])

# %%
plt.plot(data[:, 2])

# %%
plt.plot(data[:, 3])

# %%
plt.plot(data[:, 1], data[:, 2])
