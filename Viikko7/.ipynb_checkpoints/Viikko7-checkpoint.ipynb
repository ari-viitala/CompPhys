# %% [markdown]
# # PHYS-E0412 Computational Physics -Homework 7
# Ari Viitala
# 432568

# %% [markdown]
# ### a) Dimension 1. Implement a solver for the one-dimensional problem

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def oned_solve(N):
    h = 1 / (N - 1)
    
    a = np.diag(np.ones(N))
    b = np.diag(np.ones(N-1), k = 1)
    c = np.diag(np.ones(N-1), k = -1)
    
    s = (- b + 2 * a - c)
    
    s[0,0] = 1
    s[0, 1] = 0
    s[-1,-1] = 1
    s[-1, -2] = 0

    
    s *= 1 / h**2
    
    x  = np.linspace(0, 1, N)
    b = (x - 0.5)**3 - 2*(x - 0.5)
    
    b[0] = 0
    b[-1] = 0
    
    return  np.linalg.solve(s, b)

# %%
def analytical(N):
    x = np.linspace(0, 1, N)
    return -1./20 * (x-0.5) ** 5 + x**3 / 3. - x**2 / 2. +163 * x / 960. - 1./640

# %%
x = np.linspace(0,1,100)
plt.figure(1, (12, 8))
plt.plot(x, analytical(100), label = "Analytical")
for i in range(2, 10):
    N = i **2
    x  = np.linspace(0, 1, N)
    plt.plot(x, oned_solve(N), label = "N = " + str(i ** 2))

plt.legend()
plt.show()

# %%
def error(N):
    h = 1 / (N - 1)
    return np.sqrt(h) * np.linalg.norm(analytical(N) -oned_solve(N))

# %%
N = np.array(list(range(10, 1000, 50)))

errors = [error(i) for i in N]
plt.loglog(1 / (N-1), errors, marker = "x")
plt.show()

# %%
np.polyfit(np.log(1 / (N-1)), np.log(errors), 1)
# Out:
# array([ 1.9997664 , -5.85304734])

# %%
def neumann_oned_solve(N):
    h = 1 / (N - 1)
    
    a = np.diag(np.ones(N))
    b = np.diag(np.ones(N-1), k = 1)
    c = np.diag(np.ones(N-1), k = -1)
    
    s = (- b + 2 * a - c)
    
    s[0,0] = 1
    s[0, 1] = 0
    s[-1,-1] = 1
    s[-1, -2] = -1

    s *= 1 / h**2
    
    x  = np.linspace(0, 1, N)
    b = (x - 0.5)**3 - 2*(x - 0.5)
    
    b[0] = 0
    b[-1] = 0
    
    return  np.linalg.solve(s, b)

# %%
def neumann_analytic(N):
    x = np.linspace(0, 1, N)
    return -(1 / 20 * x**5 - 1/8* x**4 - 5/24* x**3 + 7/16* x **2)

# %%
x = np.linspace(0,1,100)
plt.plot(x, neumann_analytic(100), label = "Analytical")
for i in range(1, 10):
    N = i * 10
    x  = np.linspace(0, 1, N)
    plt.plot(x, neumann_oned_solve(N), label = "N = " + str(i * 10))

plt.
plt.legend()
plt.show()

# %%
def neumann_error(N):
    h = 1 / (N - 1)
    return np.sqrt(h) * np.linalg.norm(neumann_analytic(N) -neumann_oned_solve(N))

# %%
N = np.array(list(range(10, 1000, 50)))

neumann_errors = [neumann_error(i) for i in N]
errors = [error(i) for i in N]
plt.loglog(1/(N-1), errors, marker = "x")
plt.loglog(1/(N-1), neumann_errors, marker = "x")
plt.show()

# %%
np.polyfit(np.log(1 / (N-1)), np.log(neumann_errors), 1)
# Out:
# array([ 1.00224725, -1.36165818])

# %%
N = 10

D = 4 * np.diag(np.ones(N)) - np.diag(np.ones(N-1), k = -1) - np.diag(np.ones(N-1), k = 1) 
I = np.diag(np.ones(N))

# %%
s = np.diag(np.zeros(N**2))

for i in range(0, N):
        if i == 0:
            s[:N,0:2*N] = np.hstack((I,I))
        elif i == N - 1:
            s[i*N:,N*(i-1):] = np.hstack((I,I))
        else:
            s[i*N:(i+1)*N,N*(i-1):N*(i+2)] = np.hstack((-I,D,-I))
            
s *= 1 / (1 / (N-1)**2)

# %%
b = np.zeros((N,N))
x = y = np.linspace(0,1,N)

# %%
for i in range(N):
    for j in range(N):
        b[i, j] = np.exp(-((x[i] - 0.5)**2 + (y[j]-0.5)**2) / 18)
b[0,:] = 0
b[:,0] = 0
b[-1,:] = 0
b[:,-1] = 0
b = b.flatten()

# %%
z = np.linalg.solve(s, b).reshape((N,N))
z
# Out:
# array([[0.00043017, 0.002586  , 0.0029648 , 0.00303572, 0.00305027,
#         0.00305027, 0.00303572, 0.0029648 , 0.002586  , 0.00043017],
#        [0.00043017, 0.002586  , 0.0029648 , 0.00303572, 0.00305027,
#         0.00305027, 0.00303572, 0.0029648 , 0.002586  , 0.00043017],
#        [0.00043517, 0.00260491, 0.00298773, 0.00305996, 0.00307493,
#         0.00307493, 0.00305996, 0.00298773, 0.00260491, 0.00043517],
#        [0.00043407, 0.00260726, 0.00298945, 0.00306101, 0.00307565,
#         0.00307565, 0.00306101, 0.00298945, 0.00260726, 0.00043407],
#        [0.0004358 , 0.00261309, 0.00299663, 0.00306876, 0.00308364,
#         0.00308364, 0.00306876, 0.00299663, 0.00261309, 0.0004358 ],
#        [0.0004358 , 0.00261309, 0.00299663, 0.00306876, 0.00308364,
#         0.00308364, 0.00306876, 0.00299663, 0.00261309, 0.0004358 ],
#        [0.00043407, 0.00260726, 0.00298945, 0.00306101, 0.00307565,
#         0.00307565, 0.00306101, 0.00298945, 0.00260726, 0.00043407],
#        [0.00043517, 0.00260491, 0.00298773, 0.00305996, 0.00307493,
#         0.00307493, 0.00305996, 0.00298773, 0.00260491, 0.00043517],
#        [0.00043017, 0.002586  , 0.0029648 , 0.00303572, 0.00305027,
#         0.00305027, 0.00303572, 0.0029648 , 0.002586  , 0.00043017],
#        [0.00043017, 0.002586  , 0.0029648 , 0.00303572, 0.00305027,
#         0.00305027, 0.00303572, 0.0029648 , 0.002586  , 0.00043017]])

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X, Y = np.meshgrid(x, y)
# Plot the surface
ax.plot_surface(X, Y, z, color='b')

plt.show()
